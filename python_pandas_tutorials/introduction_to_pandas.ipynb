# %% [markdown]
# <div id="BBox" class="alert alert-success" style="font-family:courier;color:black;justify-content:left;">
# <h1>Introduction to Pandas</h1>
# <h2>What is Pandas? </h2>
# Pandas is an open-source data analysis and manipulation library in Python, widely used in data science, machine learning, and data engineering. It provides data structures and functions needed to efficiently work with structured data, especially tabular data (like data from databases or spreadsheets).
#
# <h2>Importance of Pandas</h2>
# <ul>
# <li><strong>Efficient Data Handling:</strong> Makes it easy to clean, filter, manipulate, and analyze data.</li>
# <li><strong>Powerful Data Analysis:</strong> Offers robust tools to perform operations on large datasets, making complex transformations easy.</li>
# <li><strong>High Compatibility: </strong>Works well with other data analysis libraries and integrates with databases, files, and visualization libraries like Matplotlib.</li>
# </ul>
#
# <h2>How Pandas Works </h2>
# Pandas primarily works with two data structures:
# <ul>
# <li><strong>Series: </strong>A one-dimensional labeled array, ideal for simple lists or arrays.</li>
# <li><strong>DataFrame:</strong> A two-dimensional labeled data structure with columns of potentially different types, akin to a table in a database or an Excel sheet.</li>
# </ul>
# </div>

# %%
# pip install pandas

# %%
import pandas as pd

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>Pandas Dataframe </h1>
# A Pandas DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). Think of it as a powerful version of an Excel spreadsheet or SQL table that allows for easy data manipulation and analysis. A DataFrame is one of the core data structures in Pandas, alongside the Series, and it is widely used for data analysis in Python.
#
# <h2>Key Properties of a DataFrame</h2>
# <ul>
# <li><strong>Two-Dimensional Structure:</strong> DataFrames are structured as a table with rows and columns, where each column can hold data of a different type (integer, float, string, etc.).</li>
#
# <li><strong>Labeled Axes: </strong>Both rows and columns in a DataFrame are labeled, making it easy to access data by row/column names or indexes.</li>
#
# <li><strong>Mutable Size:</strong> DataFrames can grow or shrink in size. You can add or remove rows and columns as needed.</li>
#
# <li><strong>Heterogeneous Data:</strong> Unlike arrays, a DataFrame can store data of different types in different columns, allowing flexibility in storing and manipulating data from real-world applications.</li>
#
# <li><strong>Data Alignment:</strong> When performing operations on DataFrames, Pandas aligns data based on row and column labels, making it easier to work with data from different sources or perform complex calculations.</li>
#
# <li><strong>Integration with Other Libraries:</strong> Pandas works well with other Python libraries like NumPy, Matplotlib, and Scikit-Learn, providing a strong ecosystem for data analysis and machine learning.</li>
# </ul>
#
# <h2>Basic Structure of a DataFrame</h2>
# A DataFrame has two primary axes:
# <ul>
# <li><strong>Index (rows):</strong> Uniquely identifies each row. Default is a numerical index, but custom indexes can also be used.</li>
# <li><strong>Columns: </strong>Each column has a name (header) and a data type (e.g., integer, float, string).</li>
# </ul>
# Here’s an example DataFrame structure:
# <table>
# <tr>
# <td></td>
# <td><strong>Name</strong></td>
# <td><strong>Age</strong></td>
# <td><strong>City</strong></td>
# </tr>
# <tr>
# <td>0</td>
# <td>Alice</td>
# <td>23</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>1</td>
# <td>Bob</td>
# <td>34</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>2</td>
# <td>John</td>
# <td>35</td>
# <td>Hyderabad</td>
# </tr>
# <tr>
# <td>3</td>
# <td>Ramesh</td>
# <td>28</td>
# <td>bangalore</td>
# </tr>
# </table>
#
# In this example: <br>
# <ul>
# <li>The Index is [0, 1, 2, 3].</li>
# <li>Columns are "Name", "Age", and "City".</li>
# <li>Each cell can hold different types of data.</li>
# </ul>
#
# <h3>How to Create a DataFrame</h3>
# You can create a DataFrame using different types of data sources, such as:
# <ul>
# <li>Lists or dictionaries</li>
# <li>CSV files, Excel files, SQL databases, or JSON files</li>
# <li>Other DataFrames</li>
# </ul>
# </div>

# %%
# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Claire', 'David'],
    'Age': [23, 34, 29, 41],
    'City': ['New York', 'Chicago', 'San Diego', 'Seattle']
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age       City
# 0   Alice   23   New York
# 1     Bob   34    Chicago
# 2  Claire   29  San Diego
# 3   David   41    Seattle

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>pd.read_csv</h1>
# <strong>What it does:</strong> Reads data from a CSV file into a DataFrame. <br>
# <strong>How it works: </strong>You provide the path to a CSV file, and it loads the data into a DataFrame for easy manipulation.<br>
# <strong>When to use:</strong> When working with data stored in CSV files, which is common in data analysis.
# </div>

# %%
xl_path = "data/country_wise_latest.csv"

df = pd.read_csv(xl_path)

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.head()</h1>
# <strong>What it does:</strong> Displays the first few rows of the DataFrame. <br>
# <strong>How it works: </strong>By default, it shows the top 5 rows, but you can specify a different number.<br>
# <strong>When to use:</strong> To get a quick glimpse of the structure and contents of the DataFrame.
# </div>

# %%
df.head(10)  # df.head(10) Displays the first 10 rows
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.tail()</h1>
# <strong>What it does:</strong> Shows the last few rows of the DataFrame. <br>
# <strong>How it works: </strong>Like head(), but displays rows from the bottom of the DataFrame.<br>
# <strong>When to use:</strong> Useful for checking the last entries in your data, such as verifying loading or indexing.
# </div>

# %%
df.tail()  # Displays the last 5 rows
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.info()</h1>
# <strong>What it does:</strong> Provides a summary of the DataFrame, including column names, data types, and non-null values. <br>
# <strong>How it works: </strong>Summarizes the structure of the DataFrame.<br>
# <strong>When to use:</strong> To understand data types and check for missing values before analysis.
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.describe()</h1>
# <strong>What it does:</strong> Generates descriptive statistics for numerical columns.<br>
# <strong>How it works: </strong>Shows mean, standard deviation, min, and max values for each numeric column.<br>
# <strong>When to use:</strong> For a quick statistical overview of your data.
# </div>

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.columns</h1>
# <strong>What it does:</strong> Lists the column names of the DataFrame.<br>
# <strong>How it works: </strong> It’s an attribute, not a function, so no parentheses are needed.<br>
# <strong>When to use:</strong> To quickly view all column names, useful for renaming or selecting columns.
# </div>

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.shape</h1>
# <strong>What it does:</strong> Returns the dimensions of the DataFrame as (rows, columns).<br>
# <strong>How it works: </strong> Provides a tuple with the row and column counts.<br>
# <strong>When to use:</strong> To understand the size of your dataset.
# </div>

# %%
df.shape
# Out:
# (187, 15)

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.drop()</h1>
# <strong>What it does:</strong> Removes specific rows or columns from the DataFrame.<br>
# <strong>How it works: </strong>  You specify the axis (0 for rows, 1 for columns) and the labels to drop.<br>
# <strong>When to use:</strong> For removing irrelevant or unnecessary data. <br><br>
# inplace=True: This means that the operation will be performed on the original DataFrame, and the DataFrame will be modified in place without returning anything. <br><br>
# inplace=False (default): The method will return a new DataFrame with the specified rows or columns dropped, leaving the original DataFrame unchanged.
# </div>

# %%
df.drop(['1 week % increase'], axis=1, inplace=True)
new_df = df.drop(['1 week change'], axis=1, inplace=False)
df.describe()
new_df.describe()

# we can use the indexes as well
df.drop([2,3,4], axis=0, inplace=True)
df.head(10)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# 12              Bahrain      39482     141      36110    3231        351
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10             18                3.50                  69.49
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.rename()</h1>
# <strong>What it does:</strong> Renames columns.<br>
# <strong>How it works: </strong>  Provides a dictionary of old and new names for renaming.<br>
# <strong>When to use:</strong> To standardize or clarify column names.<br><br>
# </div>

# %%
# Renameing the column
df.rename(columns={'Country/Region': 'Country'}, inplace=True)
df.head()
# Out:
#                Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 5           0              5                3.49                  75.58
# 6         120           2057                1.83                  43.35
# 7           6            187                1.90                  71.32
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.sort_values()</h1>
# <strong>What it does:</strong> Sorts the DataFrame by specified column(s).<br>
# <strong>How it works: </strong>  You specify the column and whether the sort is ascending or descending.<br>
# <strong>When to use:</strong>  For ordering data, useful in reporting and visualization.<br><br>
# </div>

# %%
sorted_df = df.sort_values(by='Deaths', ascending=True)
sorted_df.head(10)

sorted_df_multi = df.sort_values(by=['Country', 'Deaths'], ascending=[True, False])
sorted_df_multi.head(10)
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# 12              Bahrain      39482     141      36110    3231        351
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10             18                3.50                  69.49
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.apply()</h1>
# <strong>What it does:</strong> Applies a function along an axis of the DataFrame.<br>
# <strong>How it works: </strong> Allows custom functions to be applied row-wise or column-wise.<br>
# <strong>When to use:</strong> To create new calculations or transformations.<br><br>
# </div>

# %%
df['New deaths'] = df['New deaths'].apply(lambda x: x-1)
df.head(10)
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# 12              Bahrain      39482     141      36110    3231        351
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            9             18                3.50                  69.49
# ...

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.merge()</h1>
# <strong>What it does:</strong> Merges two DataFrames based on common columns or indexes.<br>
# <strong>How it works: </strong>  Joins the two DataFrames like SQL joins (inner, outer, left, right).<br>
# <strong>When to use:</strong> When combining data from different sources.<br><br>
# </div>

# %%
df =  pd.read_excel("data\country_wise_latest.xlsx", sheet_name="country_wise_latest")
df.rename(columns={'Country/Region': 'Country'}, inplace=True)
df = df[['Country','Confirmed']]
new_df = pd.read_csv("data\world_population.csv")
new_df.rename(columns={'Country/Territory': 'Country'}, inplace=True)
new_df = new_df[['Country','Capital', '2022 Population']]
new_df.head(4)
# Out:
#           Country    Capital  2022 Population
# 0     Afghanistan      Kabul         41128771
# 1         Albania     Tirana          2842321
# 2         Algeria    Algiers         44903225
# 3  American Samoa  Pago Pago            44273

# %%
merged_df = df.merge(new_df, on='Country')
merged_df.head(4)
# Out:
#        Country  Confirmed           Capital  2022 Population
# 0  Afghanistan      36263             Kabul         41128771
# 1      Albania       4880            Tirana          2842321
# 2      Algeria      27973           Algiers         44903225
# 3      Andorra        907  Andorra la Vella            79824

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.concat()</h1>
# <strong>What it does:</strong> Concatenates two or more DataFrames along rows or columns.<br>
# <strong>How it works: </strong>  Joins the two DataFrames like SQL joins (inner, outer, left, right).<br>
# <strong>When to use:</strong> For combining data in the same structure.<br><br>
# </div>

# %%
combined_df = pd.concat([df, new_df], axis=1)
combined_df.head(10)
# Out:
#                Country  Confirmed              Country           Capital  \
# 0          Afghanistan    36263.0          Afghanistan             Kabul
# 1              Albania     4880.0              Albania            Tirana
# 2              Algeria    27973.0              Algeria           Algiers
# 3              Andorra      907.0       American Samoa         Pago Pago
# 4               Angola      950.0              Andorra  Andorra la Vella
# 5  Antigua and Barbuda       86.0               Angola            Luanda
# 6            Argentina   167416.0             Anguilla        The Valley
# 7              Armenia    37390.0  Antigua and Barbuda      Saint John’s
# 8            Australia    15303.0            Argentina      Buenos Aires
# 9              Austria    20558.0              Armenia           Yerevan
#
#    2022 Population
# 0         41128771
# 1          2842321
# 2         44903225
# 3            44273
# 4            79824
# 5         35588987
# 6            15857
# ...

# %%
new_df = pd.read_excel("data\country_wise_latest.xlsx", sheet_name="sub_population")
new_df.rename(columns={'Country/Region': 'Country'}, inplace=True)
new_df = new_df[['Country','Confirmed']]
combined_df = pd.concat([df, new_df], axis=0)
# combined_df.reset_index(inplace=True)
combined_df.tail(10)
# Out:
#                 Country  Confirmed
# 180           Venezuela      15988
# 181             Vietnam        431
# 182  West Bank and Gaza      10621
# 183      Western Sahara         10
# 184               Yemen       1691
# 185              Zambia       4552
# 186            Zimbabwe       2704
# 0                 test1      36263
# 1                 test2       4880
# 2                 test3      27973

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.pivot_table()</h1>
# <strong>What it does:</strong> Creates a pivot table, summarizing data by groups.<br>
# <strong>How it works: </strong>  Aggregates values across specified indexes and columns.<br>
# <strong>When to use:</strong> For advanced data summaries, especially in analysis.<br><br>
# </div>

# %%
data = {
    'Salesperson': ['Alice', 'Bob', 'Alice', 'Bob', 'Alice', 'Bob'],
    'Region': ['North', 'North', 'South', 'South', 'North', 'South'],
    'Product': ['Widgets', 'Widgets', 'Gadgets', 'Widgets', 'Gadgets', 'Gadgets'],
    'Sales': [200, 150, 300, 250, 400, 350]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

pivot = df.pivot_table(
    values='Sales',            # Column to aggregate
    index='Salesperson',       # Rows
    columns=['Region', 'Product'], # Columns to pivot
    aggfunc='sum',             # Aggregation function
    fill_value=0               # Replace missing values with 0
)

print("\nPivot Table:")
print(pivot)
# Out:
# Original DataFrame:
#   Salesperson Region  Product  Sales
# 0       Alice  North  Widgets    200
# 1         Bob  North  Widgets    150
# 2       Alice  South  Gadgets    300
# 3         Bob  South  Widgets    250
# 4       Alice  North  Gadgets    400
# 5         Bob  South  Gadgets    350
#
# Pivot Table:
# Region        North           South
# Product     Gadgets Widgets Gadgets Widgets
# Salesperson
# Alice           400     200     300       0
# Bob               0     150     350     250

# %%
new_df = pd.read_csv("data\world_population.csv")
new_df.rename(columns={'Country/Territory': 'Country'}, inplace=True)
new_df = new_df[['Country','Continent', '2022 Population']]
pivot = new_df.pivot_table(
    values='2022 Population',            # Column to aggregate
    columns=['Continent'], # Columns to pivot
    aggfunc='sum',             # Aggregation function
    fill_value=0               # Replace missing values with 0
)

print("\nPivot Table:")
pivot.head(10)
# Out:
# Pivot Table:
# Continent            Africa        Asia     Europe  North America   Oceania  \
# 2022 Population  1426730932  4721383274  743147538      600296136  45038554
#
# Continent        South America
# 2022 Population      436816608

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.groupby()</h1>
# <strong>What it does:</strong> Groups data by specified columns and applies aggregation functions.<br>
# <strong>How it works: </strong> Creates a group based on unique values of the column and calculates stats like mean, sum.<br>
# <strong>When to use:</strong> For analyzing data subsets or performing grouped calculations.<br><br>
# </div>

# %%
grouped_df  = new_df.groupby('Continent').mean()
grouped_df.head(10)
# Out:
#                2022 Population
# Continent
# Africa            2.503037e+07
# Asia              9.442767e+07
# Europe            1.486295e+07
# North America     1.500740e+07
# Oceania           1.958198e+06
# South America     3.120119e+07

# %%
sub_df = new_df[new_df['Continent'] == 'Asia']
sub_df.head(5)
# Out:
#         Country Continent  2022 Population
# 0   Afghanistan      Asia         41128771
# 9       Armenia      Asia          2780469
# 13   Azerbaijan      Asia         10358074
# 15      Bahrain      Asia          1472233
# 16   Bangladesh      Asia        171186372

# %% [markdown]
# <div id="BBox" class="alert alert-info" style="font-family:courier;color:black;justify-content:left;">
# <h1>df.to_csv()</h1>
# <strong>What it does:</strong> Exports the DataFrame to a CSV file.<br>
# <strong>How it works: </strong>  Writes data to a specified path in CSV format.<br>
# <strong>When to use:</strong> When saving cleaned or transformed data for later use.<br><br>
# </div>

# %%
sub_df.to_csv('data/output.csv', index=False)
sub_df.to_excel('data/output.xlsx', sheet_name='Asia Continent',index=False)

# %%
import matplotlib.pyplot as plt

data = pd.read_csv("data/world_population.csv")
data.plot.line(x='CCA3', y='2022 Population')
plt.title("Country VS 2022 Population")
plt.show()

# %%
data.groupby("Continent")["2022 Population"].sum().plot.bar()
plt.title("Population by Continent")
plt.show()

# %%
data.groupby("CCA3")["2022 Population"].sum().nlargest(10).plot.barh()
plt.title("Top 10 Most Populous Countries")
plt.show()

# %%
data["Area (km2)"].plot.hist(bins=30)
plt.title("Area Distribution")
plt.xlabel("Area")
plt.show()

# %%
data.groupby("Continent")["2022 Population"].sum().plot.pie(autopct='%1.1f%%')
plt.title("Population by Continent")
plt.ylabel("")
plt.show()
