# %% [markdown]
# <div id="BBox" class="alert alert-success" style="font-family:courier;color:black;justify-content:left;">
# <h1>Line Plot</h1>
# <strong>What it does:</strong>
# A line plot displays data points connected by straight line segments. It’s commonly used to visualize the relationship between two continuous variables, especially trends over time. <br><br>
# <span style="font-family: Courier New, monospace; color: navy; font-weight: bold;">
# In this example, the plot() function connects the points, forming a line that visualizes the relationship between x and y.
# </span>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# make data
x = np.linspace(0, 10, 100)
y = 4 + 1 * np.sin(2 * x)
x2 = np.linspace(0, 10, 25)
y2 = 4 + 1 * np.sin(2 * x2)

# plot
fig, ax = plt.subplots()

ax.plot(x2, y2 + 2.5, 'x', markeredgewidth=2)
ax.plot(x, y, linewidth=2.0)
ax.plot(x2, y2 - 2.5, 'o-', linewidth=2)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
